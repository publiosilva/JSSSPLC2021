# %%
import matplotlib.pyplot as plt

# %%
y1 = [0.6285714285714286, 0.6285714285714286, 0.6176470588235294, 0.6176470588235294, 0.6176470588235294, 0.5, 0.5882352941176471, 0.6764705882352942, 0.6764705882352942, 0.5588235294117647]
y2 = [0.6, 0.6285714285714286, 0.5882352941176471, 0.6176470588235294, 0.5882352941176471, 0.5294117647058824, 0.5882352941176471, 0.6470588235294118, 0.5588235294117647, 0.6176470588235294]
y3 = [0.7428571428571429, 0.8285714285714286, 0.8235294117647058, 0.8235294117647058, 0.7352941176470589, 0.8823529411764706, 0.7352941176470589, 0.9411764705882353, 0.8235294117647058, 0.7647058823529411]

plt.figure(figsize=(8, 6))

plt.plot(range(1, 11), y1, '-', label="Naive Bayes")
plt.plot(range(1, 11), y2, ':', label="Logistic Regression")
plt.plot(range(1, 11), y3, '-.', label="Decision Tree")

plt.legend()
plt.xlabel("Cross-validation step")
plt.ylabel("Accuracy")
plt.show()

# %%
y1 = [0.7244279529993816, 0.6317460317460317, 0.6454248366013071, 0.6761437908496731, 0.6328282828282829, 0.5027852049910874, 0.6593137254901961, 0.6646241830065359, 0.7593582887700535, 0.6568627450980392]
y2 = [0.5083505866114562, 0.6823747680890537, 0.5441176470588235, 0.5147058823529411, 0.6862745098039216, 0.37516339869281046, 0.48670076726342704, 0.6073529411764705, 0.4330242966751918, 0.6126050420168067]
y3 = [0.8018253968253969, 0.8222222222222223, 0.8712121212121212, 0.8676470588235294, 0.7156862745098039, 0.8860294117647058, 0.8014705882352942, 0.9527310924369746, 0.8172268907563025, 0.6409897292250233]

plt.figure(figsize=(8, 6))

plt.plot(range(1, 11), y1, '-', label="Naive Bayes")
plt.plot(range(1, 11), y2, ':', label="Regressão Logística")
plt.plot(range(1, 11), y3, '-.', label="Árvore de Decisão")

plt.legend()
plt.xlabel("Etapa da validação cruzada")
plt.ylabel("Precisão")
plt.show()

# %%
y1 = [0.6285714285714286, 0.6285714285714286, 0.6176470588235294, 0.6176470588235294, 0.6176470588235294, 0.5, 0.5882352941176471, 0.6764705882352942, 0.6764705882352942, 0.5588235294117647]
y2 = [0.6, 0.6285714285714286, 0.5882352941176471, 0.6176470588235294, 0.5882352941176471, 0.5294117647058824, 0.5882352941176471, 0.6470588235294118, 0.5588235294117647, 0.6176470588235294]
y3 = [0.7428571428571429, 0.8285714285714286, 0.8235294117647058, 0.8235294117647058, 0.7352941176470589, 0.8823529411764706, 0.7352941176470589, 0.9411764705882353, 0.8235294117647058, 0.7647058823529411]

plt.figure(figsize=(8, 6))

plt.plot(range(1, 11), y1, '-', label="Naive Bayes")
plt.plot(range(1, 11), y2, ':', label="Regressão Logística")
plt.plot(range(1, 11), y3, '-.', label="Árvore de Decisão")

plt.legend()
plt.xlabel("Etapa da validação cruzada")
plt.ylabel("Recall")
plt.show()

# %%
y1 = [0.6558619158619158, 0.6263492063492063, 0.6245098039215686, 0.6242589539803163, 0.609494884910486, 0.4734191370616192, 0.5983778966131907, 0.6516204383851443, 0.6782428355957768, 0.5754528055566117]
y2 = [0.4908730158730159, 0.5542483660130719, 0.47275910364145657, 0.5571277700979678, 0.5299678695007416, 0.43014705882352944, 0.47049211841599387, 0.5747277520633922, 0.45751633986928103, 0.5318833415719229]
y3 = [0.7268095238095238, 0.8188041958041958, 0.8138205585264409, 0.8300675454128139, 0.7245989304812834, 0.8822021116138763, 0.7423738665426645, 0.941643323996265, 0.8180995475113122, 0.6886749144102086]

plt.figure(figsize=(8, 6))

plt.plot(range(1, 11), y1, '-', label="Naive Bayes")
plt.plot(range(1, 11), y2, ':', label="Regressão Logística")
plt.plot(range(1, 11), y3, '-.', label="Árvore de Decisão")

plt.legend()
plt.xlabel("Etapa da validação cruzada")
plt.ylabel("F1")
plt.show()

# %%
y1 = [0.8823495552066981, 0.8624489795918366, 0.8636635423400129, 0.8464821024563671, 0.872233893557423, 0.8910889355742297, 0.8705384076707606, 0.9353870394311572, 0.8902957336780867, 0.8911966709760828]
y2 = [0.8618367346938776, 0.8683359497645212, 0.7891847123464769, 0.8153533047834519, 0.7812368697478992, 0.8274072128851542, 0.876783020900668, 0.8343177655677656, 0.8412034044386986, 0.9103048911872441]
y3 = [0.8945368916797489, 0.8638461538461538, 0.9098173884938592, 0.9290663380736911, 0.8163515406162466, 0.9383447128851541, 0.9419871794871795, 0.9661273163111399, 0.9502626050420169, 0.8911192361560009]
plt.figure(figsize=(8, 6))

plt.plot(range(1, 11), y1, '-', label="Naive Bayes")
plt.plot(range(1, 11), y2, ':', label="Regressão Logística")
plt.plot(range(1, 11), y3, '-.', label="Árvore de Decisão")

plt.legend()
plt.xlabel("Etapa da validação cruzada")
plt.ylabel("AUC-ROC")
plt.show()
